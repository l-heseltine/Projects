# %%
import pandas as pd

# %%
pip install aquirdturtle_collapsible_headings
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Milestone 2.1 - Import data from a flat file (.csv, .xlsx)
# Milestone 3.1 - Create pandas dataframe

data_dictionary = pd.read_excel("Data_Dictionary.xlsx")
first_health_camp = pd.read_csv("First_Health_Camp_Attended.csv")
health_camp_details = pd.read_csv("Health_Camp_Detail.csv")
patient_profile = pd.read_csv("Patient_Profile.csv")
second_health_camp = pd.read_csv("Second_Health_Camp_Attended.csv")
third_health_camp = pd.read_csv("Third_Health_Camp_Attended.csv")
train = pd.read_csv("Train.csv")
test = pd.read_csv("test.csv")

# %%
#Printing pandas dataframe heads to check column names
print(data_dictionary.head())
print(first_health_camp.head())
print(health_camp_details.head())
print(patient_profile.head())
print(second_health_camp.head())
print(third_health_camp.head())
print(train.head())
print(test.head())
# Out:
#                                 Details of the Files
# 0  Health_Camp_Detail.csv – File containing Healt...
# 1  Train.csv – File containing registration detai...
# 2  Patient_Profile.csv – This file contains Patie...
# 3  First_Health_Camp_Attended.csv – This file con...
# 4  Second_Health_Camp_Attended.csv - This file co...
#    Patient_ID  Health_Camp_ID  Donation  Health_Score  Unnamed: 4
# 0      506181            6560        40      0.439024         NaN
# 1      494977            6560        20      0.097561         NaN
# 2      518680            6560        10      0.048780         NaN
# 3      509916            6560        30      0.634146         NaN
# 4      488006            6560        20      0.024390         NaN
#    Health_Camp_ID Camp_Start_Date Camp_End_Date Category1 Category2  Category3
# 0            6560       16-Aug-03     20-Aug-03     First         B          2
# 1            6530       16-Aug-03     28-Oct-03     First         C          2
# ...

# %%
patient_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37633 entries, 0 to 37632
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         37633 non-null  int64
#  1   Online_Follower    37633 non-null  int64
#  2   LinkedIn_Shared    37633 non-null  int64
#  3   Twitter_Shared     37633 non-null  int64
#  4   Facebook_Shared    37633 non-null  int64
#  5   Income             37633 non-null  object
#  6   Education_Score    37633 non-null  object
#  7   Age                37633 non-null  object
#  8   First_Interaction  37633 non-null  object
#  9   City_Type          14249 non-null  object
#  10  Employer_Category  2840 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 3.2+ MB

# %%
patient_profile.describe()
# Out:
#           Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# count   37633.000000     37633.000000     37633.000000    37633.000000
# mean   507148.408338         0.022533         0.027077        0.021603
# std     12411.747993         0.148412         0.162311        0.145387
# min    485678.000000         0.000000         0.000000        0.000000
# 25%    496393.000000         0.000000         0.000000        0.000000
# 50%    507104.000000         0.000000         0.000000        0.000000
# 75%    517882.000000         0.000000         0.000000        0.000000
# max    528657.000000         1.000000         1.000000        1.000000
#
#        Facebook_Shared
# count     37633.000000
# mean          0.023543
# std           0.151623
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000

# %%
# Milestone 3.4 - Merging Patient Profile and First Health Camp dataframes
merged_details = pd.merge(right=patient_profile, left=first_health_camp, on='Patient_ID')
merged_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         6218 non-null   int64
#  1   Health_Camp_ID     6218 non-null   int64
#  2   Donation           6218 non-null   int64
#  3   Health_Score       6218 non-null   float64
#  4   Unnamed: 4         0 non-null      float64
#  5   Online_Follower    6218 non-null   int64
#  6   LinkedIn_Shared    6218 non-null   int64
#  7   Twitter_Shared     6218 non-null   int64
#  8   Facebook_Shared    6218 non-null   int64
#  9   Income             6218 non-null   object
#  10  Education_Score    6218 non-null   object
#  11  Age                6218 non-null   object
#  12  First_Interaction  6218 non-null   object
#  13  City_Type          4451 non-null   object
#  14  Employer_Category  2300 non-null   object
# dtypes: float64(2), int64(7), object(6)
# ...

# %%
merged_details_2 = merged_details.merge(health_camp_details, on = "Health_Camp_ID")
merged_details_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6218 entries, 0 to 6217
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Patient_ID         6218 non-null   int64
#  1   Health_Camp_ID     6218 non-null   int64
#  2   Donation           6218 non-null   int64
#  3   Health_Score       6218 non-null   float64
#  4   Unnamed: 4         0 non-null      float64
#  5   Online_Follower    6218 non-null   int64
#  6   LinkedIn_Shared    6218 non-null   int64
#  7   Twitter_Shared     6218 non-null   int64
#  8   Facebook_Shared    6218 non-null   int64
#  9   Income             6218 non-null   object
#  10  Education_Score    6218 non-null   object
#  11  Age                6218 non-null   object
#  12  First_Interaction  6218 non-null   object
#  13  City_Type          4451 non-null   object
#  14  Employer_Category  2300 non-null   object
#  15  Camp_Start_Date_x  6218 non-null   object
# ...

# %%
merged_details_3= merged_details_2.merge(second_health_camp, on="Patient_ID")
merged_details_3.info
# Out:
# <bound method DataFrame.info of       Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0         506181              6560        40      0.439024         NaN
# 1         494977              6560        20      0.097561         NaN
# 2         494977              6560        20      0.097561         NaN
# 3         494977              6585        60      0.733990         NaN
# 4         494977              6585        60      0.733990         NaN
# ...          ...               ...       ...           ...         ...
# 5207      518259              6587        10      0.416667         NaN
# 5208      492886              6587        10      0.972222         NaN
# 5209      519458              6587        20      0.666667         NaN
# 5210      510192              6587        10      0.444444         NaN
# 5211      495971              6587        10      1.000000         NaN
#
#       Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared  \
# ...

# %%
details = merged_details_3.merge(third_health_camp, on="Patient_ID")
# Checking that all the information has been merged and is present
details.head()
# Out:
#    Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0      494977              6560        20      0.097561         NaN
# 1      494977              6560        20      0.097561         NaN
# 2      494977              6560        20      0.097561         NaN
# 3      494977              6560        20      0.097561         NaN
# 4      494977              6585        60      0.733990         NaN
#
#    Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared Income  \
# 0                1                1               1                0      2
# 1                1                1               1                0      2
# 2                1                1               1                0      2
# 3                1                1               1                0      2
# 4                1                1               1                0      2
#
#    ... Camp_Start_Date_y Camp_End_Date_y Category1_y Category2_y Category3_y  \
# ...

# %%
# Milestone 3.2 - Sorting 
details.sort_values(by=['Health_Score'])
# Out:
#       Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 1344      491825              6586        20      0.001667         NaN
# 1343      491825              6586        20      0.001667         NaN
# 2229      516051              6537        10      0.002075         NaN
# 2230      516051              6537        10      0.002075         NaN
# 2231      516051              6537        10      0.002075         NaN
# ...          ...               ...       ...           ...         ...
# 133       509188              6580        20      1.000000         NaN
# 134       509188              6580        20      1.000000         NaN
# 135       509188              6580        20      1.000000         NaN
# 128       509188              6580        20      1.000000         NaN
# 131       509188              6580        20      1.000000         NaN
#
#       Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared  \
# ...

# %%
# Milestone 3.2 - Indexing
details.loc[:,['Patient_ID', 'Health_Score']]
# Out:
#       Patient_ID  Health_Score
# 0         494977      0.097561
# 1         494977      0.097561
# 2         494977      0.097561
# 3         494977      0.097561
# 4         494977      0.733990
# ...          ...           ...
# 5417      499996      0.537037
# 5418      495949      0.037037
# 5419      520328      0.092593
# 5420      517824      0.648148
# 5421      517824      0.648148
#
# [5422 rows x 2 columns]

# %%
# Milestone 3.2 - Grouping
details.groupby(level=0).mean()
# Out:
#       Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0       494977.0            6560.0      20.0      0.097561         NaN
# 1       494977.0            6560.0      20.0      0.097561         NaN
# 2       494977.0            6560.0      20.0      0.097561         NaN
# 3       494977.0            6560.0      20.0      0.097561         NaN
# 4       494977.0            6585.0      60.0      0.733990         NaN
# ...          ...               ...       ...           ...         ...
# 5417    499996.0            6524.0      20.0      0.537037         NaN
# 5418    495949.0            6524.0      30.0      0.037037         NaN
# 5419    520328.0            6524.0      20.0      0.092593         NaN
# 5420    517824.0            6524.0      20.0      0.648148         NaN
# 5421    517824.0            6524.0      20.0      0.648148         NaN
#
#       Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared  \
# ...

# %%
# Milestone 3.2 - Sorting, indexing, grouping
details.loc[:,['Patient_ID', 'Health_Score']]
# Out:
#       Patient_ID  Health_Score
# 0         494977      0.097561
# 1         494977      0.097561
# 2         494977      0.097561
# 3         494977      0.097561
# 4         494977      0.733990
# ...          ...           ...
# 5417      499996      0.537037
# 5418      495949      0.037037
# 5419      520328      0.092593
# 5420      517824      0.648148
# 5421      517824      0.648148
#
# [5422 rows x 2 columns]

# %%
# Check missing values
patient_profile.isnull().sum()
# Out:
# Patient_ID               0
# Online_Follower          0
# LinkedIn_Shared          0
# Twitter_Shared           0
# Facebook_Shared          0
# Income                   0
# Education_Score          0
# Age                      0
# First_Interaction        0
# City_Type            23384
# Employer_Category    34793
# dtype: int64

# %%
# Milestone 3.3 - Drop Duplicates - attempted to drop duplicates in all columns with no results - TBC
details.drop_duplicates(subset='Health_Camp_ID', keep='first')
# Out:
#      Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0        494977              6560        20      0.097561         NaN
# 1        494977              6560        20      0.097561         NaN
# 44       493258              6560        30      0.121951         NaN
# 441      510474              6585        90      0.709360         NaN
#
#      Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared Income  \
# 0                  1                1               1                0      2
# 1                  1                1               1                0      2
# 44                 1                1               0                1      3
# 441                0                0               0                0   None
#
#      ... Camp_Start_Date_y Camp_End_Date_y Category1_y Category2_y  \
# 0    ...         16-Aug-03       20-Aug-03       First           B
# 1    ...         16-Aug-03       20-Aug-03       First           B
# ...

# %%
# Milestone 3.3 - Drop Duplicates - attempted to drop duplicates in all columns with no results - TBC
details.drop_duplicates(subset='Health_Camp_ID', keep='first')
# Out:
#      Patient_ID  Health_Camp_ID_x  Donation  Health_Score  Unnamed: 4  \
# 0        494977              6560        20      0.097561         NaN
# 1        494977              6560        20      0.097561         NaN
# 44       493258              6560        30      0.121951         NaN
# 441      510474              6585        90      0.709360         NaN
#
#      Online_Follower  LinkedIn_Shared  Twitter_Shared  Facebook_Shared Income  \
# 0                  1                1               1                0      2
# 1                  1                1               1                0      2
# 44                 1                1               0                1      3
# 441                0                0               0                0   None
#
#      ... Camp_Start_Date_y Camp_End_Date_y Category1_y Category2_y  \
# 0    ...         16-Aug-03       20-Aug-03       First           B
# 1    ...         16-Aug-03       20-Aug-03       First           B
# ...
